# %%
# Have to temporarily include the xquartz bin path to PATH so that package Xvfb
# is discoverable.
# %env PATH=$PATH:/opt/X11/bin
from pyvirtualdisplay.display import Display

virtual_display = Display(visible=False, size=(1400, 900))
virtual_display.start()
# Out:
# env: PATH=$PATH:/opt/X11/bin

# %%
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
# A sample iteration of the RL loop.
environment = gymnasium.make('LunarLander-v3')
observation, info = environment.reset()
for _ in range(20):
    action = environment.action_space.sample()
    print(f'action taken: {action}')
    observation, reward, terminated, truncated, info = environment.step(action)
    if terminated or truncated:
        print('environment is reset')
        observation, info = environment.reset()
environment.close()
# Out:
# action taken: 3
# action taken: 1
# action taken: 2
# action taken: 0
# action taken: 1
# action taken: 0
# action taken: 0
# action taken: 2
# action taken: 2
# action taken: 1
# action taken: 2
# action taken: 0
# action taken: 3
# action taken: 0
# action taken: 0
# action taken: 0
# action taken: 3
# action taken: 2
# action taken: 1
# action taken: 2

# %%
print('Observation space:')
print(environment.observation_space.shape)
print(f'sample observation: {environment.observation_space.sample()}')
print('Action space')
print(environment.action_space.shape)
print(f'sample action space: {environment.action_space.sample()}')
# Out:
# Observation space:
# (8,)
# sample observation: [-1.6106519  -0.08835039  3.262047   -0.1892082   5.601258    7.6346636
#   0.9470163   0.16108984]
# Action space
# ()
# sample action space: 2

# %%
environment = make_vec_env('LunarLander-v3', n_envs=16)

# %%
model = PPO('MlpPolicy', environment, verbose=1)
model.learn(total_timesteps=int(2e5))
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.9     |
# |    ep_rew_mean     | -196     |
# | time/              |          |
# |    fps             | 11790    |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 32768    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97          |
# |    ep_rew_mean          | -158        |
# | time/                   |             |
# |    fps                  | 6129        |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011826916 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00313    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 223         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00766    |
# |    value_loss           | 905         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 5271        |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.013157884 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.447       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 350         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 113          |
# |    ep_rew_mean          | -74.5        |
# | time/                   |              |
# |    fps                  | 4905         |
# |    iterations           | 4            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0124379555 |
# |    clip_fraction        | 0.189        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.612        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.7         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0177      |
# |    value_loss           | 202          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 132         |
# |    ep_rew_mean          | -47.1       |
# | time/                   |             |
# |    fps                  | 4683        |
# |    iterations           | 5           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.015724733 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.772       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.4        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.025      |
# |    value_loss           | 96.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 149         |
# |    ep_rew_mean          | -33.4       |
# | time/                   |             |
# |    fps                  | 4422        |
# |    iterations           | 6           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.015351899 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.8        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 46.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 308         |
# |    ep_rew_mean          | -18.8       |
# | time/                   |             |
# |    fps                  | 3908        |
# |    iterations           | 7           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.014971004 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.4        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 39.8        |
# -----------------------------------------

# %%
model = PPO(
    policy='MlpPolicy',
    env=environment,
    n_steps=1024,
    batch_size=64,
    n_epochs=4,
    gamma=0.999,
    gae_lambda=0.98,
    ent_coef=0.01,
    verbose=1,
)
model.learn(total_timesteps=1_000_000)
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89.5     |
# |    ep_rew_mean     | -180     |
# | time/              |          |
# |    fps             | 13571    |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.2        |
# |    ep_rew_mean          | -142        |
# | time/                   |             |
# |    fps                  | 8745        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008011678 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -2.71e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.29e+03    |
# |    n_updates            | 4           |
# |    policy_gradient_loss | -0.0053     |
# |    value_loss           | 5.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.9        |
# |    ep_rew_mean          | -136        |
# | time/                   |             |
# |    fps                  | 8109        |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006363217 |
# |    clip_fraction        | 0.0258      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00198     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 705         |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00343    |
# |    value_loss           | 2.11e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.6        |
# |    ep_rew_mean          | -127        |
# | time/                   |             |
# |    fps                  | 7908        |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008463431 |
# |    clip_fraction        | 0.0784      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00753    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 576         |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00661    |
# |    value_loss           | 1.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.4        |
# |    ep_rew_mean          | -121        |
# | time/                   |             |
# |    fps                  | 7751        |
# |    iterations           | 5           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009311328 |
# |    clip_fraction        | 0.0602      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.000892   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 638         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00436    |
# |    value_loss           | 904         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.7        |
# |    ep_rew_mean          | -98.4       |
# | time/                   |             |
# |    fps                  | 7636        |
# |    iterations           | 6           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009825224 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 2.15e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 298         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00673    |
# |    value_loss           | 688         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.9         |
# |    ep_rew_mean          | -95.4        |
# | time/                   |              |
# |    fps                  | 7547         |
# |    iterations           | 7            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0066880453 |
# |    clip_fraction        | 0.0707       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -6.71e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 284          |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.0037      |
# |    value_loss           | 572          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.6        |
# |    ep_rew_mean          | -78.3       |
# | time/                   |             |
# |    fps                  | 7375        |
# |    iterations           | 8           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.011084676 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -6.54e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 284         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.00557    |
# |    value_loss           | 576         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -59.7        |
# | time/                   |              |
# |    fps                  | 7262         |
# |    iterations           | 9            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0075597195 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | -1.25e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 194          |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.00377     |
# |    value_loss           | 498          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | -39.6        |
# | time/                   |              |
# |    fps                  | 7212         |
# |    iterations           | 10           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0066022007 |
# |    clip_fraction        | 0.0461       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | -0.00177     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 165          |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.00478     |
# |    value_loss           | 370          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | -27          |
# | time/                   |              |
# |    fps                  | 7163         |
# |    iterations           | 11           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0067404257 |
# |    clip_fraction        | 0.0535       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | -6.68e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 167          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00372     |
# |    value_loss           | 473          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 117          |
# |    ep_rew_mean          | -25.6        |
# | time/                   |              |
# |    fps                  | 7063         |
# |    iterations           | 12           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0064331098 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -8.34e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 205          |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 506          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -18.3       |
# | time/                   |             |
# |    fps                  | 6941        |
# |    iterations           | 13          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.007745115 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 292         |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00402    |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | -8.64       |
# | time/                   |             |
# |    fps                  | 6542        |
# |    iterations           | 14          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.005195214 |
# |    clip_fraction        | 0.0339      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 1.13e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 317         |
# |    n_updates            | 52          |
# |    policy_gradient_loss | -0.00216    |
# |    value_loss           | 610         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | -11.1        |
# | time/                   |              |
# |    fps                  | 6207         |
# |    iterations           | 15           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0073104487 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.000378     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 309          |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 642          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 235         |
# |    ep_rew_mean          | -7.55       |
# | time/                   |             |
# |    fps                  | 5777        |
# |    iterations           | 16          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.011380155 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.000536    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 374         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00368    |
# |    value_loss           | 682         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 290          |
# |    ep_rew_mean          | -4.47        |
# | time/                   |              |
# |    fps                  | 5307         |
# |    iterations           | 17           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0075260988 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.00482      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 270          |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 576          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 384         |
# |    ep_rew_mean          | 8.36        |
# | time/                   |             |
# |    fps                  | 4897        |
# |    iterations           | 18          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.007192947 |
# |    clip_fraction        | 0.0419      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 132         |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.00313    |
# |    value_loss           | 387         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 434          |
# |    ep_rew_mean          | 6.59         |
# | time/                   |              |
# |    fps                  | 4580         |
# |    iterations           | 19           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0065640695 |
# |    clip_fraction        | 0.0409       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.463        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 119          |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00452     |
# |    value_loss           | 309          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 526          |
# |    ep_rew_mean          | 15.2         |
# | time/                   |              |
# |    fps                  | 4225         |
# |    iterations           | 20           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0024895365 |
# |    clip_fraction        | 0.00621      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.475        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 129          |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 436          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 595        |
# |    ep_rew_mean          | 19.3       |
# | time/                   |            |
# |    fps                  | 3953       |
# |    iterations           | 21         |
# |    time_elapsed         | 87         |
# |    total_timesteps      | 344064     |
# | train/                  |            |
# |    approx_kl            | 0.00507446 |
# |    clip_fraction        | 0.0358     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.21      |
# |    explained_variance   | 0.615      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 63.3       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00122   |
# |    value_loss           | 179        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 675          |
# |    ep_rew_mean          | 22.1         |
# | time/                   |              |
# |    fps                  | 3717         |
# |    iterations           | 22           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0075780186 |
# |    clip_fraction        | 0.0742       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 143          |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00356     |
# |    value_loss           | 159          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 749         |
# |    ep_rew_mean          | 33.7        |
# | time/                   |             |
# |    fps                  | 3575        |
# |    iterations           | 23          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.005766319 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.1        |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.00148    |
# |    value_loss           | 83.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 813          |
# |    ep_rew_mean          | 47.1         |
# | time/                   |              |
# |    fps                  | 3462         |
# |    iterations           | 24           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0043245014 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.863        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87           |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 130          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 813          |
# |    ep_rew_mean          | 52.9         |
# | time/                   |              |
# |    fps                  | 3355         |
# |    iterations           | 25           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0047643036 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.881        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.7         |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 116          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 834         |
# |    ep_rew_mean          | 55.4        |
# | time/                   |             |
# |    fps                  | 3241        |
# |    iterations           | 26          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.003889932 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48          |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00117    |
# |    value_loss           | 105         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 852          |
# |    ep_rew_mean          | 63.5         |
# | time/                   |              |
# |    fps                  | 3147         |
# |    iterations           | 27           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0063797096 |
# |    clip_fraction        | 0.0578       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.913        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.1         |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.00233     |
# |    value_loss           | 78           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 871          |
# |    ep_rew_mean          | 65.1         |
# | time/                   |              |
# |    fps                  | 3052         |
# |    iterations           | 28           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0045257593 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.942        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.2         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.000856    |
# |    value_loss           | 44.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 892          |
# |    ep_rew_mean          | 68.6         |
# | time/                   |              |
# |    fps                  | 2996         |
# |    iterations           | 29           |
# |    time_elapsed         | 158          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0065879924 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.872        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25           |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 82.8         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 922        |
# |    ep_rew_mean          | 75.3       |
# | time/                   |            |
# |    fps                  | 2940       |
# |    iterations           | 30         |
# |    time_elapsed         | 167        |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.00368904 |
# |    clip_fraction        | 0.0391     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | 0.88       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.3       |
# |    n_updates            | 116        |
# |    policy_gradient_loss | -0.0019    |
# |    value_loss           | 110        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 949         |
# |    ep_rew_mean          | 85.7        |
# | time/                   |             |
# |    fps                  | 2879        |
# |    iterations           | 31          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.004714192 |
# |    clip_fraction        | 0.0371      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.6        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00125    |
# |    value_loss           | 37.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 937         |
# |    ep_rew_mean          | 91.7        |
# | time/                   |             |
# |    fps                  | 2818        |
# |    iterations           | 32          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.004088919 |
# |    clip_fraction        | 0.0261      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.48        |
# |    n_updates            | 124         |
# |    policy_gradient_loss | -0.00069    |
# |    value_loss           | 16.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 938          |
# |    ep_rew_mean          | 93           |
# | time/                   |              |
# |    fps                  | 2773         |
# |    iterations           | 33           |
# |    time_elapsed         | 194          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0030561548 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.94         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.31         |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.000147    |
# |    value_loss           | 51.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 914          |
# |    ep_rew_mean          | 101          |
# | time/                   |              |
# |    fps                  | 2729         |
# |    iterations           | 34           |
# |    time_elapsed         | 204          |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0035661852 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.986       |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.75         |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.000498    |
# |    value_loss           | 29.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 943         |
# |    ep_rew_mean          | 110         |
# | time/                   |             |
# |    fps                  | 2693        |
# |    iterations           | 35          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.004211288 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.1        |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -0.000739   |
# |    value_loss           | 82.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 937         |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 2659        |
# |    iterations           | 36          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.005830175 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.36        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000271   |
# |    value_loss           | 10.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 943         |
# |    ep_rew_mean          | 115         |
# | time/                   |             |
# |    fps                  | 2630        |
# |    iterations           | 37          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.006318812 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14        |
# |    n_updates            | 144         |
# |    policy_gradient_loss | -0.00189    |
# |    value_loss           | 18.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 949         |
# |    ep_rew_mean          | 119         |
# | time/                   |             |
# |    fps                  | 2609        |
# |    iterations           | 38          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.009429129 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.45        |
# |    n_updates            | 148         |
# |    policy_gradient_loss | -0.000623   |
# |    value_loss           | 8.24        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 125          |
# | time/                   |              |
# |    fps                  | 2591         |
# |    iterations           | 39           |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0041806567 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.27         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | 0.000177     |
# |    value_loss           | 14.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 978          |
# |    ep_rew_mean          | 131          |
# | time/                   |              |
# |    fps                  | 2574         |
# |    iterations           | 40           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 655360       |
# | train/                  |              |
# |    approx_kl            | 0.0037513701 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.92         |
# |    n_updates            | 156          |
# |    policy_gradient_loss | -0.000491    |
# |    value_loss           | 6.98         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 956         |
# |    ep_rew_mean          | 132         |
# | time/                   |             |
# |    fps                  | 2558        |
# |    iterations           | 41          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.004953527 |
# |    clip_fraction        | 0.03        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.717       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000296   |
# |    value_loss           | 22.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 955          |
# |    ep_rew_mean          | 134          |
# | time/                   |              |
# |    fps                  | 2545         |
# |    iterations           | 42           |
# |    time_elapsed         | 270          |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0068294303 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.927       |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.73         |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -0.000949    |
# |    value_loss           | 36.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 949         |
# |    ep_rew_mean          | 138         |
# | time/                   |             |
# |    fps                  | 2525        |
# |    iterations           | 43          |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 704512      |
# | train/                  |             |
# |    approx_kl            | 0.003854634 |
# |    clip_fraction        | 0.0412      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.887      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.79        |
# |    n_updates            | 168         |
# |    policy_gradient_loss | 3.21e-05    |
# |    value_loss           | 11.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 956          |
# |    ep_rew_mean          | 142          |
# | time/                   |              |
# |    fps                  | 2510         |
# |    iterations           | 44           |
# |    time_elapsed         | 287          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0034142705 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.886       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.64         |
# |    n_updates            | 172          |
# |    policy_gradient_loss | 0.000513     |
# |    value_loss           | 17           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 938         |
# |    ep_rew_mean          | 141         |
# | time/                   |             |
# |    fps                  | 2504        |
# |    iterations           | 45          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.004345254 |
# |    clip_fraction        | 0.0497      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.338       |
# |    n_updates            | 176         |
# |    policy_gradient_loss | -0.000822   |
# |    value_loss           | 2.77        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 938          |
# |    ep_rew_mean          | 142          |
# | time/                   |              |
# |    fps                  | 2497         |
# |    iterations           | 46           |
# |    time_elapsed         | 301          |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0036187884 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.839       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.23         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000261    |
# |    value_loss           | 48.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 937         |
# |    ep_rew_mean          | 144         |
# | time/                   |             |
# |    fps                  | 2488        |
# |    iterations           | 47          |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.003080042 |
# |    clip_fraction        | 0.0269      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.827      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.55        |
# |    n_updates            | 184         |
# |    policy_gradient_loss | -0.000776   |
# |    value_loss           | 23.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 921        |
# |    ep_rew_mean          | 142        |
# | time/                   |            |
# |    fps                  | 2479       |
# |    iterations           | 48         |
# |    time_elapsed         | 317        |
# |    total_timesteps      | 786432     |
# | train/                  |            |
# |    approx_kl            | 0.00360415 |
# |    clip_fraction        | 0.0314     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.867     |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 15.5       |
# |    n_updates            | 188        |
# |    policy_gradient_loss | 5.11e-05   |
# |    value_loss           | 29         |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 928          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 2475         |
# |    iterations           | 49           |
# |    time_elapsed         | 324          |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0043728454 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.836       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.797        |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.000817    |
# |    value_loss           | 21.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 915         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 2466        |
# |    iterations           | 50          |
# |    time_elapsed         | 332         |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.003934428 |
# |    clip_fraction        | 0.0659      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.549       |
# |    n_updates            | 196         |
# |    policy_gradient_loss | -0.000978   |
# |    value_loss           | 3.6         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 924          |
# |    ep_rew_mean          | 142          |
# | time/                   |              |
# |    fps                  | 2462         |
# |    iterations           | 51           |
# |    time_elapsed         | 339          |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0038835728 |
# |    clip_fraction        | 0.0331       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.841       |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.3         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00034     |
# |    value_loss           | 30.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 918          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 2459         |
# |    iterations           | 52           |
# |    time_elapsed         | 346          |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0029123325 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.839       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.74         |
# |    n_updates            | 204          |
# |    policy_gradient_loss | 0.000234     |
# |    value_loss           | 17.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 917          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 2456         |
# |    iterations           | 53           |
# |    time_elapsed         | 353          |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0039756373 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.848       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85.2         |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.000866    |
# |    value_loss           | 45.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 902         |
# |    ep_rew_mean          | 143         |
# | time/                   |             |
# |    fps                  | 2456        |
# |    iterations           | 54          |
# |    time_elapsed         | 360         |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.004015285 |
# |    clip_fraction        | 0.0404      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.9        |
# |    n_updates            | 212         |
# |    policy_gradient_loss | -5.71e-05   |
# |    value_loss           | 30.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 904          |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 2453         |
# |    iterations           | 55           |
# |    time_elapsed         | 367          |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0035992742 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.843       |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.52         |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.000696    |
# |    value_loss           | 43.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 855          |
# |    ep_rew_mean          | 159          |
# | time/                   |              |
# |    fps                  | 2454         |
# |    iterations           | 56           |
# |    time_elapsed         | 373          |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0046943584 |
# |    clip_fraction        | 0.0372       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.777       |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36           |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.000273     |
# |    value_loss           | 38           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 799          |
# |    ep_rew_mean          | 168          |
# | time/                   |              |
# |    fps                  | 2454         |
# |    iterations           | 57           |
# |    time_elapsed         | 380          |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0055769933 |
# |    clip_fraction        | 0.0703       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.697       |
# |    explained_variance   | 0.867        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.5         |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.00234     |
# |    value_loss           | 237          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 651          |
# |    ep_rew_mean          | 205          |
# | time/                   |              |
# |    fps                  | 2459         |
# |    iterations           | 58           |
# |    time_elapsed         | 386          |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0045584287 |
# |    clip_fraction        | 0.0466       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.673       |
# |    explained_variance   | 0.863        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.2         |
# |    n_updates            | 228          |
# |    policy_gradient_loss | -0.00255     |
# |    value_loss           | 233          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 459         |
# |    ep_rew_mean          | 227         |
# | time/                   |             |
# |    fps                  | 2472        |
# |    iterations           | 59          |
# |    time_elapsed         | 391         |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.009709384 |
# |    clip_fraction        | 0.0661      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.7        |
# |    explained_variance   | 0.722       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 116         |
# |    n_updates            | 232         |
# |    policy_gradient_loss | -0.0043     |
# |    value_loss           | 367         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 410          |
# |    ep_rew_mean          | 238          |
# | time/                   |              |
# |    fps                  | 2480         |
# |    iterations           | 60           |
# |    time_elapsed         | 396          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0056495965 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.765       |
# |    explained_variance   | 0.713        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.3         |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 297          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 375         |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 2494        |
# |    iterations           | 61          |
# |    time_elapsed         | 400         |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.004664494 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 120         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000859   |
# |    value_loss           | 260         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 327         |
# |    ep_rew_mean          | 247         |
# | time/                   |             |
# |    fps                  | 2506        |
# |    iterations           | 62          |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 1015808     |
# | train/                  |             |
# |    approx_kl            | 0.004496025 |
# |    clip_fraction        | 0.0456      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.753      |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 77.1        |
# |    n_updates            | 244         |
# |    policy_gradient_loss | -0.00111    |
# |    value_loss           | 276         |
# -----------------------------------------

# %%
model_name = 'ppo-LunarLander-v3'
model.save(model_name)

# %%
eval_environment = Monitor(gymnasium.make(
    'LunarLander-v3', render_mode='rgb_array'))
mean_reward, std_reward = evaluate_policy(
    model, eval_environment, n_eval_episodes=10, deterministic=True)
print(f'mean_reward={mean_reward:.2f} +/- {std_reward}')
# Out:
# mean_reward=274.17 +/- 22.13096038029531

# %%
notebook_login()

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

env_id = 'LunarLander-v3'
model_arch = 'PPO'
repo_id = f'rodmosc/ppo-{env_id}'
eval_env = DummyVecEnv(
    [lambda: Monitor(gymnasium.make(env_id, render_mode='rgb_array'))])
package_to_hub(
    model=model,
    model_name=model_name,
    model_architecture=model_arch,
    env_id=env_id,
    eval_env=eval_env,
    repo_id=repo_id,
    commit_message='Upload PPO LunarLander-v3 trained agent.'
)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# Saving video to /var/folders/zd/6xd2w7tx4dz9dc2hp_9jpsww0000gn/T/tmphqystngj/-step-0-to-step-1000.mp4
# MoviePy - Building video /var/folders/zd/6xd2w7tx4dz9dc2hp_9jpsww0000gn/T/tmphqystngj/-step-0-to-step-1000.mp4.
# MoviePy - Writing video /var/folders/zd/6xd2w7tx4dz9dc2hp_9jpsww0000gn/T/tmphqystngj/-step-0-to-step-1000.mp4
# sh: ffmpeg: command not found
# MoviePy - Done !
# MoviePy - video ready /var/folders/zd/6xd2w7tx4dz9dc2hp_9jpsww0000gn/T/tmphqystngj/-step-0-to-step-1000.mp4
# ℹ Pushing repo rodmosc/ppo-LunarLander-v3 to the Hugging Face Hub
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/rodmosc/ppo-LunarLander-v3/tree/main/
# CommitInfo(commit_url='https://huggingface.co/rodmosc/ppo-LunarLander-v3/commit/db8c1e7d7631973f7a38c090c3ca0520c9bfe877', commit_message='Upload PPO LunarLander-v3 trained agent.', commit_description='', oid='db8c1e7d7631973f7a38c090c3ca0520c9bfe877', pr_url=None, repo_url=RepoUrl('https://huggingface.co/rodmosc/ppo-LunarLander-v3', endpoint='https://huggingface.co', repo_type='model', repo_id='rodmosc/ppo-LunarLander-v3'), pr_revision=None, pr_num=None)

# %%
from huggingface_sb3 import load_from_hub

repo_id = 'rodmosc/ppo-LunarLander-v3'
filename = 'ppo-LunarLander-v3.zip'
custom_objects = {
    'learning_rate': 0.0,
    'lr_schedule': lambda _: 0.0,
    'clip_range': lambda _: 0.0,
}
checkpoint = load_from_hub(repo_id, filename)
model = PPO.load(checkpoint, custom_objects=custom_objects,
                 print_system_info=True)
# Out:
# ppo-LunarLander-v3.zip:   0%|          | 0.00/150k [00:00<?, ?B/s]
# == CURRENT SYSTEM INFO ==
# - OS: macOS-15.6.1-arm64-arm-64bit Darwin Kernel Version 24.6.0: Mon Jul 14 11:30:40 PDT 2025; root:xnu-11417.140.69~1/RELEASE_ARM64_T6041
# - Python: 3.11.13
# - Stable-Baselines3: 2.7.0
# - PyTorch: 2.9.0
# - GPU Enabled: False
# - Numpy: 2.2.6
# - Cloudpickle: 3.1.2
# - Gymnasium: 1.2.2
#
# == SAVED MODEL SYSTEM INFO ==
# - OS: macOS-15.6.1-arm64-arm-64bit Darwin Kernel Version 24.6.0: Mon Jul 14 11:30:40 PDT 2025; root:xnu-11417.140.69~1/RELEASE_ARM64_T6041
# - Python: 3.11.13
# - Stable-Baselines3: 2.7.0
# - PyTorch: 2.9.0
# - GPU Enabled: False
# - Numpy: 2.2.6
# - Cloudpickle: 3.1.2
# - Gymnasium: 1.2.2

# %%
eval_env = Monitor(gymnasium.make('LunarLander-v3'))
mean_reward, std_reward = evaluate_policy(
    model, eval_env, n_eval_episodes=10, deterministic=True)
print(f'mean_reward={mean_reward:.2f} +/- {std_reward}')
# Out:
# mean_reward=258.89 +/- 20.811088434062675
